# %%
ROOT = '/home/yuli_zeira/Cognatehood/'

ENG = 'eng'
SPA = 'spa'

BI_INSERTION_0 = ROOT + 'char_weights/alphabet/new/insertion_0'
BI_DELETION_0 = ROOT + 'char_weights/alphabet/new/deletion_0'
BI_SUBSTITUTION_0 = ROOT + 'char_weights/alphabet/new/substitution_0'

BI_INSERTION_1 = ROOT + 'char_weights/alphabet/new/insertion_1'
BI_DELETION_1 = ROOT + 'char_weights/alphabet/new/deletion_1'
BI_SUBSTITUTION_1 = ROOT + 'char_weights/alphabet/new/substitution_1'

TRI_INSERTION = ROOT + 'char_weights/alphabet/new/insertion_tri'
TRI_DELETION = ROOT + 'char_weights/alphabet/new/deletion_tri'
TRI_SUBSTITUTION = ROOT + 'char_weights/alphabet/new/substitution_tri'

IPA_BI_INSERTION_0 = ROOT + 'char_weights/ipa/new/ipa_insertion_0'
IPA_BI_DELETION_0 = ROOT + 'char_weights/ipa/new/ipa_deletion_0'
IPA_BI_SUBSTITUTION_0 = ROOT + 'char_weights/ipa/new/ipa_substitution_0'

IPA_BI_INSERTION_1 = ROOT + 'char_weights/ipa/new/ipa_insertion_1'
IPA_BI_DELETION_1 = ROOT + 'char_weights/ipa/new/ipa_deletion_1'
IPA_BI_SUBSTITUTION_1 = ROOT + 'char_weights/ipa/new/ipa_substitution_1'

IPA_TRI_INSERTION = ROOT + 'char_weights/ipa/new/ipa_insertion_tri'
IPA_TRI_DELETION = ROOT + 'char_weights/ipa/new/ipa_deletion_tri'
IPA_TRI_SUBSTITUTION = ROOT + 'char_weights/ipa/new/ipa_substitution_tri'

# %%
import stanza
import epitran

# %%
ABC = 'abcdefghijklmnopqrstuvwxyz'
SPANISH_ABC = 'abcdefghijklmnopqrstuvwxyzñúóéáíü'
EN_BIGRAMS = [(i, j) for i in ABC for j in ABC] + [(i, '') for i in ABC] + [('', i) for i in ABC]
SP_BIGRAMS = [(i, j) for i in SPANISH_ABC for j in SPANISH_ABC] + [(i, '') for i in SPANISH_ABC] + [('', i) for i in SPANISH_ABC]

# Dicts of weights for first char edit distance:
INSERTION_0 = dict([(i, 1.0) for i in SP_BIGRAMS])
DELETION_0 = dict([(i, 1.0) for i in EN_BIGRAMS])
SUBSTITUTION_0 = dict([((i, j), 1.0) for i in EN_BIGRAMS for j in SP_BIGRAMS])

# Dicts of weights for second char edit distance:
INSERTION_1 = dict([(i, 1.0) for i in SP_BIGRAMS])
DELETION_1 = dict([(i, 1.0) for i in EN_BIGRAMS])
SUBSTITUTION_1 = dict([((i, j), 1.0) for i in EN_BIGRAMS for j in SP_BIGRAMS])

COGNATES_LIST = ROOT + '/char_weights/cognate_list.txt'

# %%
IPA_CHARS = ['p', 'e', 'ɾ', 'o', 'i', 's', 'x', 'a', 'l', 'k', 'd', 'n', 'we',
             'b', 't', 'm', 'ɡ', 'f', 'u', 'jo', 't͡ʃ', 'ja', 'ʝ', 'je', '',
             'si', 'se', 'xe', 'wa', 'w', 'ɡi', 'r', 'ks', 'ɡw', 'wi', 'ɡe',
             'xi', 'ju', 'wo', 'ʃ', 'ɲ', 't͡ɬ', 't͡s', 'æ', 'ɹ̩', 'ð', 'ɪ', 'j',
             'd͡ʒ', 'ʌ', 'ɑ', 'ə', 'h', 'ɹ', 'ŋ', 'ɔ', 'ʊ', 'z', 'v', 'ɛ', 'θ',
             'ʒ']

IPA_BIGRAMS = [(i, j) for i in IPA_CHARS for j in IPA_CHARS]

# Dicts of weights for first char edit distance:
INSERTION_0 = dict([(i, 1.0) for i in IPA_BIGRAMS])
DELETION_0 = dict([(i, 1.0) for i in IPA_BIGRAMS])
SUBSTITUTION_0 = dict([((i, j), 1.0) for i in IPA_BIGRAMS for j in IPA_BIGRAMS])

# Dicts of weights for second char edit distance:
INSERTION_1 = dict([(i, 1.0) for i in IPA_BIGRAMS])
DELETION_1 = dict([(i, 1.0) for i in IPA_BIGRAMS])
SUBSTITUTION_1 = dict([((i, j), 1.0) for i in IPA_BIGRAMS for j in IPA_BIGRAMS])

COGNATES_LIST = ROOT + '/char_weights/pronunciation_cognates'

# %%
from collections import Counter
import json
import pickle
from numpy import argmin


# Class of cognates with weights saved in dictionary:

class Cognates:

    def __init__(self, cognates_file: str, insertion, deletion, substitution,
                 ind: int, ipa=False):
        self._is_ipa = ipa
        self._ind = ind
        self._cognates_file = cognates_file
        self._cognates = self.read_cognates()
        self._insertion = insertion
        self._deletion = deletion
        self._substitution = substitution
        self._operations = list()
        self.make_n_gram = [self.make_n_gram_first, self.make_n_gram_second][ind]

    def read_cognates(self) -> list[tuple[str, str]]:
        if self._is_ipa:
            with open(self._cognates_file, 'rb') as ff:
                cognates_list = pickle.load(ff)
        else:
            cognates_list = list()
            with open(self._cognates_file, 'r', encoding='utf-8') as ff:
                for line in ff.readlines():
                    cognate_pair = line.split(',')
                    cognate_pair = (cognate_pair[0].lower(), cognate_pair[1][:-1].lower())
                    cognates_list.append(cognate_pair)
        return cognates_list

    def make_n_gram_first(self, word, k: int) -> tuple[str]:
        if self._is_ipa:
            tup = [''] + word
        else:
            tup = [''] + list(word)
        new_tup = tup[k: k + 2]
        return tuple(new_tup)

    def make_n_gram_second(self, word, k: int) -> tuple[str]:
        if self._is_ipa:
            tup = word + ['']
        else:
            tup = list(word) + ['']
        new_tup = tup[k: k + 2]
        return tuple(new_tup)

    def initialize(self, word_1: str, word_2: str) -> tuple[dict, dict]:
        # Set up:
        all_operations, distances = {(-1, -1): []}, {(-1, -1): 0}
        # Initialize the arrays:
        for i in range(len(word_1)):
            distances[(i, -1)] = self._deletion[self.make_n_gram(word_1, i)] + distances[(i - 1, -1)]
            all_operations[(i, -1)] = all_operations[(i - 1, -1)] + [('Deletion', self.make_n_gram(word_1, i))]
        for j in range(len(word_2)):
            distances[(-1, j)] = self._insertion[self.make_n_gram(word_2, j)] + distances[(-1, j - 1)]
            all_operations[(-1, j)] = all_operations[(-1, j - 1)] + [('Insertion', self.make_n_gram(word_2, j))]
        return all_operations, distances

    def edit_distance(self, word_1: str, word_2: str) -> float:
        # Set up:
        if not self._is_ipa:
            word_1, word_2 = word_1.lower(), word_2.lower()
        len_1, len_2 = len(word_1), len(word_2)
        all_operations, distances = self.initialize(word_1, word_2)
        # Fill distances and operations:
        for i in range(len_1):
            for j in range(len_2):
                w1_ngram, w2_ngram = self.make_n_gram(word_1, i), self.make_n_gram(word_2, j)
                if word_1[i] == word_2[j]:
                    cost = 0
                    c = []
                else:
                    cost = self._substitution[(w1_ngram, w2_ngram)]
                    c = [('Substitution', (w1_ngram, w2_ngram))]
                curr_operations = [all_operations[(i, j - 1)] + [('Insertion', w2_ngram)],
                                   all_operations[(i - 1, j)] + [('Deletion', w1_ngram)],
                                   all_operations[(i - 1, j - 1)] + c]
                curr_distances = [distances[(i, j - 1)] + self._insertion[w2_ngram],
                                  distances[(i - 1, j)] + self._deletion[w1_ngram],
                                  distances[(i - 1, j - 1)] + cost]
                ind = argmin(curr_distances)
                distances[(i, j)] = curr_distances[ind]
                all_operations[(i, j)] = curr_operations[ind]
        self._operations += all_operations[(len_1 - 1, len_2 - 1)]
        return distances[(len_1 - 1, len_2 - 1)]

    def set_weights(self):
        for pair in self._cognates:
            self.edit_distance(pair[0], pair[1])
        all_ops = Counter(self._operations)
        for op in all_ops.keys():
            print(op, all_ops[op], float(1 / (2 * all_ops[op] + 1)))
            if op[0] == 'Insertion':
                self._insertion[op[1]] = float(1 / (2 * all_ops[op] + 1))
            elif op[0] == 'Deletion':
                self._deletion[op[1]] = float(1 / (2 * all_ops[op] + 1))
            else:
                self._substitution[op[1]] = float(1 / (2 * all_ops[op] + 1))
            print(op[0], float(1 / (2 * all_ops[op] + 1)))

    def save_weights(self, ins: str, de: str, sub: str):
        with open(ins, 'wb') as f:
            pickle.dump(self._insertion, f)
        with open(de, 'wb') as f:
            pickle.dump(self._deletion, f,)
        with open(sub, 'wb') as f:
            pickle.dump(self._substitution, f)

    def test_distances(self):
        with open(f'test_bigrams_{self._ind}.txt', 'w') as f:
            for pair in self._cognates:
                e = self.edit_distance(pair[0], pair[1])
                f.write(f'{pair[0]} - {pair[1]}: {e}\n')

# %%
cognates_first = Cognates(COGNATES_LIST, INSERTION_0, DELETION_0, SUBSTITUTION_0, 0)
cognates_second = Cognates(COGNATES_LIST, INSERTION_1, DELETION_1, SUBSTITUTION_1, 1)

# %%
cognates_first.set_weights()
cognates_second.set_weights()
# Out:
# ('Substitution', (('', 'a'), ('', 'á'))) 11 0.043478260869565216
# Substitution 0.043478260869565216
# ('Substitution', (('c', 'u'), ('c', 'o'))) 6 0.07692307692307693
# Substitution 0.07692307692307693
# ('Deletion', ('u', 's')) 62 0.008
# Deletion 0.008
# ('Insertion', ('n', 'a')) 38 0.012987012987012988
# Insertion 0.012987012987012988
# ('Insertion', ('a', 'r')) 203 0.002457002457002457
# Insertion 0.002457002457002457
# ('Substitution', (('n', 'e'), ('n', 'a'))) 39 0.012658227848101266
# Substitution 0.012658227848101266
# ('Insertion', ('d', 'o')) 179 0.002785515320334262
# Insertion 0.002785515320334262
# ('Substitution', (('n', 'm'), ('n', 'o'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Deletion', ('m', 'e')) 9 0.05263157894736842
# Deletion 0.05263157894736842
# ('Deletion', ('e', 'n')) 14 0.034482758620689655
# Deletion 0.034482758620689655
# ('Deletion', ('n', 't')) 16 0.030303030303030304
# Deletion 0.030303030303030304
# ('Deletion', ('b', 'b')) 2 0.2
# Deletion 0.2
# ('Substitution', (('a', 't'), ('a', 'r'))) 85 0.005847953216374269
# Substitution 0.005847953216374269
# ('Deletion', ('t', 'e')) 150 0.0033222591362126247
# Deletion 0.0033222591362126247
# ('Substitution', (('a', 't'), ('a', 'c'))) 176 0.0028328611898017
# Substitution 0.0028328611898017
# ('Substitution', (('i', 'o'), ('i', 'ó'))) 319 0.001564945226917058
# Substitution 0.001564945226917058
# ('Insertion', ('', 'h')) 2 0.2
# Insertion 0.2
# ('Substitution', (('i', 't'), ('i', 'd'))) 104 0.004784688995215311
# Substitution 0.004784688995215311
# ('Substitution', (('t', 'y'), ('d', 'a'))) 109 0.0045662100456621
# Substitution 0.0045662100456621
# ('Insertion', ('a', 'd')) 134 0.0037174721189591076
# Insertion 0.0037174721189591076
# ('Substitution', (('i', 's'), ('i', 'r'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Deletion', ('s', 'h')) 6 0.07692307692307693
# Deletion 0.07692307692307693
# ('Substitution', (('i', 's'), ('i', 'c'))) 8 0.058823529411764705
# Substitution 0.058823529411764705
# ('Substitution', (('s', 'h'), ('c', 'i'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Substitution', (('h', 'm'), ('i', 'ó'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('i', 't'), ('i', 'c'))) 47 0.010526315789473684
# Substitution 0.010526315789473684
# ('Insertion', ('m', 'o')) 40 0.012345679012345678
# Insertion 0.012345679012345678
# ('Insertion', ('t', 'a')) 91 0.00546448087431694
# Insertion 0.00546448087431694
# ('Substitution', (('s', 'u'), ('s', 'o'))) 16 0.030303030303030304
# Substitution 0.030303030303030304
# ('Deletion', ('u', 'm')) 29 0.01694915254237288
# Deletion 0.01694915254237288
# ('Deletion', ('b', 'o')) 2 0.2
# Deletion 0.2
# ('Insertion', ('d', 'a')) 28 0.017543859649122806
# Insertion 0.017543859649122806
# ('Insertion', ('t', 'o')) 143 0.003484320557491289
# Insertion 0.003484320557491289
# ('Substitution', (('s', 's'), ('s', 'o'))) 12 0.04
# Substitution 0.04
# ('Deletion', ('s', 's')) 81 0.006134969325153374
# Deletion 0.006134969325153374
# ('Substitution', (('a', 'b'), ('a', 'u'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('c', 'e'), ('c', 'i'))) 114 0.004366812227074236
# Substitution 0.004366812227074236
# ('Insertion', ('i', 'a')) 145 0.003436426116838488
# Insertion 0.003436426116838488
# ('Insertion', ('t', 'e')) 199 0.002506265664160401
# Insertion 0.002506265664160401
# ('Substitution', (('t', 'e'), ('t', 'o'))) 29 0.01694915254237288
# Substitution 0.01694915254237288
# ('Insertion', ('a', 'm')) 7 0.06666666666666667
# Insertion 0.06666666666666667
# ('Substitution', (('e', 'l'), ('e', 'n'))) 5 0.09090909090909091
# Substitution 0.09090909090909091
# ('Substitution', (('l', 'y'), ('n', 't'))) 5 0.09090909090909091
# Substitution 0.09090909090909091
# ('Insertion', ('b', 'e')) 2 0.2
# Insertion 0.2
# ('Insertion', ('e', 'r')) 47 0.010526315789473684
# Insertion 0.010526315789473684
# ('Substitution', (('t', 'a'), ('t', 'e'))) 15 0.03225806451612903
# Substitution 0.03225806451612903
# ('Deletion', ('a', 'i')) 28 0.017543859649122806
# Deletion 0.017543859649122806
# ('Insertion', ('n', 'e')) 16 0.030303030303030304
# Insertion 0.030303030303030304
# ('Insertion', ('r', 's')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Insertion', ('s', 'e')) 5 0.09090909090909091
# Insertion 0.09090909090909091
# ('Substitution', (('c', 't'), ('c', 'c'))) 40 0.012345679012345678
# Substitution 0.012345679012345678
# ('Substitution', (('t', 'l'), ('t', 'e'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Substitution', (('l', 'y'), ('e', 'm'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Insertion', ('m', 'e')) 14 0.034482758620689655
# Insertion 0.034482758620689655
# ('Insertion', ('e', 'n')) 31 0.015873015873015872
# Insertion 0.015873015873015872
# ('Insertion', ('n', 't')) 28 0.017543859649122806
# Insertion 0.017543859649122806
# ('Substitution', (('s', 'e'), ('s', 'a'))) 26 0.018867924528301886
# Substitution 0.018867924528301886
# ('Substitution', (('b', 'y'), ('b', 'i'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('s', 's'), ('s', 'm'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('d', 'e'), ('d', 'é'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Insertion', ('c', 'o')) 112 0.0044444444444444444
# Insertion 0.0044444444444444444
# ('Substitution', (('m', 'y'), ('m', 'i'))) 8 0.058823529411764705
# Substitution 0.058823529411764705
# ('Deletion', ('c', 'c')) 34 0.014492753623188406
# Deletion 0.014492753623188406
# ('Deletion', ('a', 'n')) 21 0.023255813953488372
# Deletion 0.023255813953488372
# ('Insertion', ('i', 'ó')) 9 0.05263157894736842
# Insertion 0.05263157894736842
# ('Insertion', ('ó', 'n')) 8 0.058823529411764705
# Insertion 0.058823529411764705
# ('Substitution', (('r', 'y'), ('r', 'i'))) 72 0.006896551724137931
# Substitution 0.006896551724137931
# ('Insertion', ('i', 'o')) 103 0.004830917874396135
# Insertion 0.004830917874396135
# ('Deletion', ('m', 'm')) 22 0.022222222222222223
# Deletion 0.022222222222222223
# ('Substitution', (('n', 'i'), ('n', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('i', 'e')) 5 0.09090909090909091
# Deletion 0.09090909090909091
# ('Substitution', (('a', 'n'), ('a', 'ñ'))) 6 0.07692307692307693
# Substitution 0.07692307692307693
# ('Substitution', (('n', 'y'), ('ñ', 'a'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('c', 'c'), ('c', 'u'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('c', 'o'), ('u', 'e'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('a', 't'), ('a', 'd'))) 50 0.009900990099009901
# Substitution 0.009900990099009901
# ('Substitution', (('c', 'c'), ('c', 'o'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Deletion', ('c', 'u')) 2 0.2
# Deletion 0.2
# ('Substitution', (('t', 'o'), ('t', 'u'))) 5 0.09090909090909091
# Substitution 0.09090909090909091
# ('Insertion', ('m', 'b')) 4 0.1111111111111111
# Insertion 0.1111111111111111
# ('Insertion', ('b', 'r')) 7 0.06666666666666667
# Insertion 0.06666666666666667
# ('Insertion', ('r', 'a')) 31 0.015873015873015872
# Insertion 0.015873015873015872
# ('Substitution', (('m', 'e'), ('m', 'b'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('a', 'c'), ('a', 'd'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('r', 'e'), ('r', 'i'))) 12 0.04
# Substitution 0.04
# ('Insertion', ('i', 'r')) 68 0.0072992700729927005
# Insertion 0.0072992700729927005
# ('Substitution', (('b', 'a'), ('b', 'á'))) 5 0.09090909090909091
# Substitution 0.09090909090909091
# ('Insertion', ('t', 'u')) 5 0.09090909090909091
# Insertion 0.09090909090909091
# ('Insertion', ('u', 'a')) 2 0.2
# Insertion 0.2
# ('Substitution', (('v', 'e'), ('v', 'o'))) 57 0.008695652173913044
# Substitution 0.008695652173913044
# ('Substitution', (('t', 'i'), ('d', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('e', 's'), ('i', 'z'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('d', 'd')) 4 0.1111111111111111
# Deletion 0.1111111111111111
# ('Substitution', (('e', 'q'), ('e', 'c'))) 9 0.05263157894736842
# Substitution 0.05263157894736842
# ('Substitution', (('t', 'e'), ('d', 'o'))) 25 0.0196078431372549
# Substitution 0.0196078431372549
# ('Substitution', (('d', 'j'), ('d', 'y'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('c', 'y'), ('c', 'i'))) 27 0.01818181818181818
# Substitution 0.01818181818181818
# ('Deletion', ('a', 'd')) 7 0.06666666666666667
# Deletion 0.06666666666666667
# ('Substitution', (('a', 'd'), ('a', 'l'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('a', 'l'), ('a', 'n'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('r', 'e'), ('r', 'a'))) 64 0.007751937984496124
# Substitution 0.007751937984496124
# ('Insertion', ('t', 'i')) 27 0.01818181818181818
# Insertion 0.01818181818181818
# ('Substitution', (('p', 't'), ('p', 'c'))) 9 0.05263157894736842
# Substitution 0.05263157894736842
# ('Substitution', (('n', 'c'), ('n', 'z'))) 9 0.05263157894736842
# Substitution 0.05263157894736842
# ('Substitution', (('c', 'e'), ('z', 'a'))) 17 0.02857142857142857
# Substitution 0.02857142857142857
# ('Deletion', ('', 'a')) 2 0.2
# Deletion 0.2
# ('Substitution', (('v', 'a'), ('v', 'e'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('a', 'g'), ('a', 'j'))) 12 0.04
# Substitution 0.04
# ('Substitution', (('g', 'e'), ('j', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('i', 'c'), ('i', 's'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('c', 'e'), ('s', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('a', 'd'), ('a', 'b'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('d', 'v')) 1 0.3333333333333333
# Deletion 0.3333333333333333
# ('Substitution', (('o', 'c'), ('o', 'g'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('a', 'e'), ('a', 'é'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('r', 'i'), ('r', 'e'))) 14 0.034482758620689655
# Substitution 0.034482758620689655
# ('Substitution', (('i', 'a'), ('e', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('a', 'l')) 71 0.006993006993006993
# Deletion 0.006993006993006993
# ('Substitution', (('d', 'y'), ('d', 'i'))) 10 0.047619047619047616
# Substitution 0.047619047619047616
# ('Substitution', (('n', 'a'), ('n', 'á'))) 6 0.07692307692307693
# Substitution 0.07692307692307693
# ('Substitution', (('t', 'h'), ('t', 'é'))) 7 0.06666666666666667
# Substitution 0.06666666666666667
# ('Deletion', ('h', 'e')) 23 0.02127659574468085
# Deletion 0.02127659574468085
# ('Deletion', ('f', 'f')) 37 0.013333333333333334
# Deletion 0.013333333333333334
# ('Substitution', (('t', 'e'), ('t', 'a'))) 36 0.0136986301369863
# Substitution 0.0136986301369863
# ('Insertion', ('m', 'a')) 34 0.014492753623188406
# Insertion 0.014492753623188406
# ('Insertion', ('n', 'o')) 33 0.014925373134328358
# Insertion 0.014925373134328358
# ('Deletion', ('g', 'g')) 6 0.07692307692307693
# Deletion 0.07692307692307693
# ('Deletion', ('l', 'e')) 35 0.014084507042253521
# Deletion 0.014084507042253521
# ('Deletion', ('a', 't')) 34 0.014492753623188406
# Deletion 0.014492753623188406
# ('Substitution', (('n', 'y'), ('n', 'í'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Insertion', ('í', 'a')) 47 0.010526315789473684
# Insertion 0.010526315789473684
# ('Substitution', (('i', 'a'), ('i', 'o'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Substitution', (('e', 'e'), ('a', 'd'))) 2 0.2
# Substitution 0.2
# ('Insertion', ('r', 'e')) 16 0.030303030303030304
# Insertion 0.030303030303030304
# ('Substitution', (('a', 'i'), ('a', 'e'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('r', 'o')) 49 0.010101010101010102
# Insertion 0.010101010101010102
# ('Substitution', (('n', 'e'), ('n', 'o'))) 29 0.01694915254237288
# Substitution 0.01694915254237288
# ('Substitution', (('h', 'o'), ('h', 'ó'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('o', 'v'), ('o', 'b'))) 9 0.05263157894736842
# Substitution 0.05263157894736842
# ('Substitution', (('v', 'e'), ('b', 'a'))) 5 0.09090909090909091
# Substitution 0.09090909090909091
# ('Insertion', ('c', 'a')) 53 0.009345794392523364
# Insertion 0.009345794392523364
# ('Deletion', ('t', 'h')) 52 0.009523809523809525
# Deletion 0.009523809523809525
# ('Substitution', (('l', 'l'), ('l', 'é'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('l', 'l')) 55 0.009009009009009009
# Deletion 0.009009009009009009
# ('Substitution', (('a', 'c'), ('a', 'q'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Insertion', ('q', 'u')) 10 0.047619047619047616
# Insertion 0.047619047619047616
# ('Insertion', ('u', 'e')) 19 0.02564102564102564
# Insertion 0.02564102564102564
# ('Substitution', (('v', 'e'), ('v', 'a'))) 18 0.02702702702702703
# Substitution 0.02702702702702703
# ('Substitution', (('n', 'u'), ('n', 'i'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('u', 'm'), ('i', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('n', 'u'), ('n', 'o'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Substitution', (('', 'a'), ('', 'e'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('a', 's'), ('a', 'j'))) 2 0.2
# Substitution 0.2
# ('Deletion', ('o', 'u')) 108 0.004608294930875576
# Deletion 0.004608294930875576
# ('Insertion', ('s', 'o')) 45 0.01098901098901099
# Insertion 0.01098901098901099
# ('Deletion', ('m', 'i')) 2 0.2
# Deletion 0.2
# ('Substitution', (('a', 'm'), ('a', 'n'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('m', 'p'), ('n', 'f'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Deletion', ('p', 'h')) 51 0.009708737864077669
# Deletion 0.009708737864077669
# ('Substitution', (('l', 'e'), ('l', 'i'))) 6 0.07692307692307693
# Substitution 0.07692307692307693
# ('Deletion', ('d', 'e')) 19 0.02564102564102564
# Deletion 0.02564102564102564
# ('Substitution', (('g', 'y'), ('g', 'í'))) 15 0.03225806451612903
# Substitution 0.03225806451612903
# ('Substitution', (('l', 'y'), ('l', 'i'))) 12 0.04
# Substitution 0.04
# ('Substitution', (('y', 's'), ('i', 'z'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('s', 'e'), ('z', 'a'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Substitution', (('z', 'e'), ('z', 'a'))) 17 0.02857142857142857
# Substitution 0.02857142857142857
# ('Substitution', (('m', 'y'), ('m', 'í'))) 5 0.09090909090909091
# Substitution 0.09090909090909091
# ('Substitution', (('i', 'e'), ('i', 'a'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Substitution', (('n', 't'), ('n', 'o'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('n', 'e'), ('n', 'é'))) 9 0.05263157894736842
# Substitution 0.05263157894736842
# ('Insertion', ('g', 'u')) 4 0.1111111111111111
# Insertion 0.1111111111111111
# ('Substitution', (('l', 'e'), ('l', 'o'))) 25 0.0196078431372549
# Substitution 0.0196078431372549
# ('Deletion', ('u', 'i')) 2 0.2
# Deletion 0.2
# ('Substitution', (('s', 'h'), ('s', 't'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('n', 'n')) 11 0.043478260869565216
# Deletion 0.043478260869565216
# ('Deletion', ('n', 'o')) 8 0.058823529411764705
# Deletion 0.058823529411764705
# ('Substitution', (('e', 'm'), ('i', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('n', 'o'), ('n', 'ó'))) 12 0.04
# Substitution 0.04
# ('Substitution', (('n', 'y'), ('n', 'i'))) 6 0.07692307692307693
# Substitution 0.07692307692307693
# ('Substitution', (('t', 'h'), ('t', 'í'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Substitution', (('h', 'y'), ('í', 'a'))) 8 0.058823529411764705
# Substitution 0.058823529411764705
# ('Substitution', (('i', 'q'), ('i', 'g'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('u', 'e'), ('u', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('u', 'i'), ('u', 'e'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('i', 't'), ('e', 'd'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Substitution', (('n', 'x'), ('n', 's'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('e', 't'), ('e', 'd'))) 6 0.07692307692307693
# Substitution 0.07692307692307693
# ('Deletion', ('p', 'p')) 30 0.01639344262295082
# Deletion 0.01639344262295082
# ('Substitution', (('t', 'u'), ('t', 'o'))) 7 0.06666666666666667
# Substitution 0.06666666666666667
# ('Substitution', (('p', 'p'), ('p', 'a'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Substitution', (('e', 'a'), ('e', 'c'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Insertion', ('c', 'e')) 8 0.058823529411764705
# Insertion 0.058823529411764705
# ('Deletion', ('p', 'e')) 2 0.2
# Deletion 0.2
# ('Substitution', (('r', 'a'), ('r', 'i'))) 2 0.2
# Substitution 0.2
# ('Insertion', ('i', 'e')) 13 0.037037037037037035
# Insertion 0.037037037037037035
# ('Insertion', ('d', 'i')) 12 0.04
# Insertion 0.04
# ('Substitution', (('s', 'e'), ('s', 'o'))) 31 0.015873015873015872
# Substitution 0.015873015873015872
# ('Substitution', (('i', 'e'), ('i', 'c'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Insertion', ('i', 'c')) 25 0.0196078431372549
# Insertion 0.0196078431372549
# ('Deletion', ('p', 'r')) 2 0.2
# Deletion 0.2
# ('Substitution', (('b', 'i'), ('b', 'e'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('i', 'c')) 6 0.07692307692307693
# Deletion 0.07692307692307693
# ('Substitution', (('c', 'h'), ('c', 'o'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('r', 'c'), ('r', 'q'))) 7 0.06666666666666667
# Substitution 0.06666666666666667
# ('Substitution', (('c', 'h'), ('q', 'u'))) 17 0.02857142857142857
# Substitution 0.02857142857142857
# ('Deletion', ('h', 'a')) 5 0.09090909090909091
# Deletion 0.09090909090909091
# ('Substitution', (('l', 'o'), ('l', 'ó'))) 11 0.043478260869565216
# Substitution 0.043478260869565216
# ('Substitution', (('c', 'a'), ('c', 'o'))) 41 0.012048192771084338
# Substitution 0.012048192771084338
# ('Deletion', ('c', 'h')) 35 0.014084507042253521
# Deletion 0.014084507042253521
# ('Substitution', (('t', 'y'), ('t', 'i'))) 11 0.043478260869565216
# Substitution 0.043478260869565216
# ('Substitution', (('p', 'e'), ('p', 'o'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Substitution', (('r', 'a'), ('r', 'á'))) 21 0.023255813953488372
# Substitution 0.023255813953488372
# ('Substitution', (('m', 'e'), ('m', 'é'))) 11 0.043478260869565216
# Substitution 0.043478260869565216
# ('Substitution', (('i', 'v'), ('i', 'b'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Substitution', (('s', 'e'), ('s', 'é'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('t', 'i'), ('t', 'í'))) 10 0.047619047619047616
# Substitution 0.047619047619047616
# ('Insertion', ('c', 'u')) 9 0.05263157894736842
# Insertion 0.05263157894736842
# ('Substitution', (('r', 'y'), ('r', 'í'))) 12 0.04
# Substitution 0.04
# ('Insertion', ('d', 'e')) 31 0.015873015873015872
# Insertion 0.015873015873015872
# ('Substitution', (('d', 'a'), ('d', 'e'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Substitution', (('d', 'i'), ('d', 'e'))) 29 0.01694915254237288
# Substitution 0.01694915254237288
# ('Substitution', (('n', 'g'), ('n', 't'))) 11 0.043478260869565216
# Substitution 0.043478260869565216
# ('Insertion', ('l', 't')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Substitution', (('s', 's'), ('s', 'e'))) 5 0.09090909090909091
# Substitution 0.09090909090909091
# ('Deletion', ('s', 'a')) 2 0.2
# Deletion 0.2
# ('Deletion', ('t', 'i')) 19 0.02564102564102564
# Deletion 0.02564102564102564
# ('Deletion', ('o', 'n')) 28 0.017543859649122806
# Deletion 0.017543859649122806
# ('Deletion', ('a', 'u')) 3 0.14285714285714285
# Deletion 0.14285714285714285
# ('Substitution', (('a', 's'), ('e', 'n'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('l', 'e'), ('l', 'a'))) 17 0.02857142857142857
# Substitution 0.02857142857142857
# ('Substitution', (('s', 's'), ('s', 'i'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Deletion', ('s', 'e')) 7 0.06666666666666667
# Deletion 0.06666666666666667
# ('Substitution', (('m', 'b'), ('m', 'i'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('l', 'y'), ('l', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('m', 'e'), ('m', 'i'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Substitution', (('s', 'k'), ('s', 'c'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('s', 'p'), ('s', 'f'))) 9 0.05263157894736842
# Substitution 0.05263157894736842
# ('Deletion', ('s', 't')) 8 0.058823529411764705
# Deletion 0.058823529411764705
# ('Substitution', (('r', 'o'), ('r', 'ó'))) 15 0.03225806451612903
# Substitution 0.03225806451612903
# ('Substitution', (('m', 'e'), ('m', 'o'))) 5 0.09090909090909091
# Substitution 0.09090909090909091
# ('Deletion', ('e', 'r')) 12 0.04
# Deletion 0.04
# ('Substitution', (('o', 'p'), ('o', 'f'))) 8 0.058823529411764705
# Substitution 0.058823529411764705
# ('Substitution', (('p', 'h'), ('f', 'í'))) 11 0.043478260869565216
# Substitution 0.043478260869565216
# ('Deletion', ('h', 'y')) 7 0.06666666666666667
# Deletion 0.06666666666666667
# ('Substitution', (('c', 's'), ('c', 'a'))) 6 0.07692307692307693
# Substitution 0.07692307692307693
# ('Substitution', (('s', 'y'), ('s', 'i'))) 14 0.034482758620689655
# Substitution 0.034482758620689655
# ('Substitution', (('m', 'm'), ('m', 'é'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('s', 'y'), ('s', 'í'))) 8 0.058823529411764705
# Substitution 0.058823529411764705
# ('Substitution', (('y', 'm'), ('í', 'n'))) 2 0.2
# Substitution 0.2
# ('Deletion', ('m', 'p')) 7 0.06666666666666667
# Deletion 0.06666666666666667
# ('Substitution', (('t', 'a'), ('t', 'á'))) 16 0.030303030303030304
# Substitution 0.030303030303030304
# ('Deletion', ('i', 's')) 7 0.06666666666666667
# Deletion 0.06666666666666667
# ('Insertion', ('r', 'i')) 18 0.02702702702702703
# Insertion 0.02702702702702703
# ('Substitution', (('l', 'e'), ('l', 'é'))) 8 0.058823529411764705
# Substitution 0.058823529411764705
# ('Substitution', (('m', 'o'), ('m', 'ó'))) 8 0.058823529411764705
# Substitution 0.058823529411764705
# ('Substitution', (('p', 'h'), ('f', 'é'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('t', 'o'), ('t', 'ó'))) 13 0.037037037037037035
# Substitution 0.037037037037037035
# ('Substitution', (('i', 'u'), ('i', 'o'))) 16 0.030303030303030304
# Substitution 0.030303030303030304
# ('Deletion', ('t', 't')) 16 0.030303030303030304
# Deletion 0.030303030303030304
# ('Substitution', (('c', 'k'), ('c', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('n', 't'), ('n', 'c'))) 23 0.02127659574468085
# Substitution 0.02127659574468085
# ('Substitution', (('t', 'i'), ('t', 'o'))) 2 0.2
# Substitution 0.2
# ('Deletion', ('i', 'v')) 6 0.07692307692307693
# Deletion 0.07692307692307693
# ('Deletion', ('v', 'e')) 10 0.047619047619047616
# Deletion 0.047619047619047616
# ('Substitution', (('t', 'i'), ('t', 'a'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Substitution', (('i', 'v'), ('a', 'm'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('a', 'c'), ('a', 'e'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('c', 't'), ('e', 'r'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('u', 't'), ('u', 'i'))) 7 0.06666666666666667
# Substitution 0.06666666666666667
# ('Substitution', (('t', 'e'), ('i', 'r'))) 5 0.09090909090909091
# Substitution 0.09090909090909091
# ('Substitution', (('t', 'y'), ('t', 'í'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('a', 'c'), ('a', 'z'))) 10 0.047619047619047616
# Substitution 0.047619047619047616
# ('Deletion', ('c', 'i')) 9 0.05263157894736842
# Deletion 0.05263157894736842
# ('Deletion', ('i', 'o')) 11 0.043478260869565216
# Deletion 0.043478260869565216
# ('Substitution', (('i', 't'), ('i', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('t', 'y')) 7 0.06666666666666667
# Deletion 0.06666666666666667
# ('Substitution', (('t', 'o'), ('t', 'i'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('o', 'r'), ('i', 'v'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('r', 'y'), ('v', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('u', 'g')) 2 0.2
# Deletion 0.2
# ('Deletion', ('t', 'a')) 3 0.14285714285714285
# Deletion 0.14285714285714285
# ('Substitution', (('g', 'u'), ('g', 'o'))) 8 0.058823529411764705
# Substitution 0.058823529411764705
# ('Substitution', (('r', 'e'), ('r', 'o'))) 14 0.034482758620689655
# Substitution 0.034482758620689655
# ('Substitution', (('a', 'p'), ('a', 'f'))) 13 0.037037037037037035
# Substitution 0.037037037037037035
# ('Substitution', (('p', 'h'), ('f', 'o'))) 7 0.06666666666666667
# Substitution 0.06666666666666667
# ('Substitution', (('t', 'e'), ('t', 'i'))) 9 0.05263157894736842
# Substitution 0.05263157894736842
# ('Insertion', ('i', 'z')) 4 0.1111111111111111
# Insertion 0.1111111111111111
# ('Insertion', ('z', 'a')) 7 0.06666666666666667
# Insertion 0.06666666666666667
# ('Substitution', (('m', 'a'), ('m', 'á'))) 14 0.034482758620689655
# Substitution 0.034482758620689655
# ('Substitution', (('o', 'b'), ('ó', 'v'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Deletion', ('r', 'y')) 8 0.058823529411764705
# Deletion 0.058823529411764705
# ('Substitution', (('u', 'e'), ('i', 'd'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('r', 'e')) 16 0.030303030303030304
# Deletion 0.030303030303030304
# ('Substitution', (('b', 'a'), ('b', 'e'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('b', 'y'), ('b', 'é'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('e', 'a')) 6 0.07692307692307693
# Insertion 0.07692307692307693
# ('Substitution', (('c', 'o'), ('c', 'ó'))) 9 0.05263157894736842
# Substitution 0.05263157894736842
# ('Deletion', ('n', 'y')) 1 0.3333333333333333
# Deletion 0.3333333333333333
# ('Substitution', (('n', 'k'), ('n', 'c'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Substitution', (('n', 'k'), ('n', 'q'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('n', 'n'), ('n', 'd'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('r', 'i'), ('r', 'o'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Deletion', ('i', 'a')) 12 0.04
# Deletion 0.04
# ('Substitution', (('r', 'k'), ('r', 'c'))) 5 0.09090909090909091
# Substitution 0.09090909090909091
# ('Insertion', ('r', 'r')) 9 0.05263157894736842
# Insertion 0.05263157894736842
# ('Substitution', (('o', 'q'), ('o', 'c'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Substitution', (('q', 'u'), ('c', 'o'))) 6 0.07692307692307693
# Substitution 0.07692307692307693
# ('Deletion', ('u', 'e')) 20 0.024390243902439025
# Deletion 0.024390243902439025
# ('Substitution', (('d', 'e'), ('d', 'a'))) 7 0.06666666666666667
# Substitution 0.06666666666666667
# ('Deletion', ('r', 'i')) 6 0.07692307692307693
# Deletion 0.07692307692307693
# ('Substitution', (('b', 'a'), ('b', 'é'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('é', 'i')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Substitution', (('b', 'a'), ('b', 'o'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Substitution', (('s', 'i'), ('s', 'e'))) 8 0.058823529411764705
# Substitution 0.058823529411764705
# ('Substitution', (('s', 'k'), ('s', 'q'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('t', 't'), ('t', 'a'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Substitution', (('l', 'e'), ('l', 'l'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Insertion', ('l', 'a')) 13 0.037037037037037035
# Insertion 0.037037037037037035
# ('Substitution', (('a', 'y'), ('a', 'h'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('h', 'í')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Deletion', ('n', 'e')) 12 0.04
# Deletion 0.04
# ('Deletion', ('c', 't')) 16 0.030303030303030304
# Deletion 0.030303030303030304
# ('Insertion', ('c', 'i')) 18 0.02702702702702703
# Insertion 0.02702702702702703
# ('Substitution', (('b', 'i'), ('b', 'í'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('e', 't')) 2 0.2
# Insertion 0.2
# ('Substitution', (('g', 'u'), ('g', 'ü'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('u', 'a'), ('ü', 'e'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('l', 'e')) 6 0.07692307692307693
# Insertion 0.07692307692307693
# ('Substitution', (('d', 'i'), ('d', 'í'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Substitution', (('t', 'h'), ('t', 'o'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Substitution', (('o', 'c'), ('o', 'q'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Substitution', (('c', 'k'), ('q', 'u'))) 2 0.2
# Substitution 0.2
# ('Deletion', ('l', 'o')) 2 0.2
# Deletion 0.2
# ('Insertion', ('', 'a')) 7 0.06666666666666667
# Insertion 0.06666666666666667
# ('Deletion', ('o', 'a')) 7 0.06666666666666667
# Deletion 0.06666666666666667
# ('Insertion', ('b', 'a')) 5 0.09090909090909091
# Insertion 0.09090909090909091
# ('Substitution', (('t', 't'), ('t', 'e'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('r', 'd')) 5 0.09090909090909091
# Deletion 0.09090909090909091
# ('Substitution', (('v', 'i'), ('v', 'e'))) 8 0.058823529411764705
# Substitution 0.058823529411764705
# ('Substitution', (('e', 'f'), ('e', 'v'))) 2 0.2
# Substitution 0.2
# ('Insertion', ('v', 'e')) 3 0.14285714285714285
# Insertion 0.14285714285714285
# ('Deletion', ('l', 'i')) 6 0.07692307692307693
# Deletion 0.07692307692307693
# ('Substitution', (('m', 'i'), ('m', 'o'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Deletion', ('i', 'n')) 9 0.05263157894736842
# Deletion 0.05263157894736842
# ('Substitution', (('n', 'z'), ('n', 'c'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Deletion', ('d', 'h')) 1 0.3333333333333333
# Deletion 0.3333333333333333
# ('Substitution', (('b', 'u'), ('b', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('t', 't'), ('t', 'ó'))) 2 0.2
# Substitution 0.2
# ('Deletion', ('t', 'o')) 6 0.07692307692307693
# Deletion 0.07692307692307693
# ('Substitution', (('', 'c'), ('', 'g'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('d', 'a'), ('d', 'á'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('r', 'i'), ('r', 'í'))) 16 0.030303030303030304
# Substitution 0.030303030303030304
# ('Substitution', (('c', 'a'), ('c', 'á'))) 10 0.047619047619047616
# Substitution 0.047619047619047616
# ('Deletion', ('l', 'a')) 3 0.14285714285714285
# Deletion 0.14285714285714285
# ('Substitution', (('l', 'u'), ('l', 'o'))) 5 0.09090909090909091
# Substitution 0.09090909090909091
# ('Insertion', ('l', 'l')) 6 0.07692307692307693
# Insertion 0.07692307692307693
# ('Insertion', ('l', 'o')) 16 0.030303030303030304
# Insertion 0.030303030303030304
# ('Substitution', (('m', 'e'), ('m', 'a'))) 13 0.037037037037037035
# Substitution 0.037037037037037035
# ('Deletion', ('m', 'o')) 2 0.2
# Deletion 0.2
# ('Insertion', ('p', 'a')) 10 0.047619047619047616
# Insertion 0.047619047619047616
# ('Deletion', ('i', 'g')) 3 0.14285714285714285
# Deletion 0.14285714285714285
# ('Substitution', (('p', 'u'), ('p', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('n', 'n'), ('ñ', 'ó'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('n', 'y'), ('ñ', 'ó'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('y', 'o')) 1 0.3333333333333333
# Deletion 0.3333333333333333
# ('Substitution', (('a', 'b'), ('a', 'z'))) 2 0.2
# Substitution 0.2
# ('Deletion', ('b', 'l')) 3 0.14285714285714285
# Deletion 0.14285714285714285
# ('Substitution', (('r', 'i'), ('r', 'a'))) 5 0.09090909090909091
# Substitution 0.09090909090909091
# ('Substitution', (('i', 's'), ('a', 'z'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('s', 'o'), ('z', 'ó'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Substitution', (('a', 'p'), ('a', 'b'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('p', 'e'), ('b', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('c', 'e'), ('c', 'h'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('h', 'o')) 8 0.058823529411764705
# Insertion 0.058823529411764705
# ('Substitution', (('c', 'i'), ('c', 'h'))) 2 0.2
# Substitution 0.2
# ('Insertion', ('n', 'i')) 4 0.1111111111111111
# Insertion 0.1111111111111111
# ('Insertion', ('p', 'i')) 3 0.14285714285714285
# Insertion 0.14285714285714285
# ('Substitution', (('r', 'e'), ('r', 'r'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('e', 's'), ('i', 'c'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('s', 's'), ('c', 'i'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('m', 'i'), ('m', 'í'))) 6 0.07692307692307693
# Substitution 0.07692307692307693
# ('Substitution', (('n', 'i'), ('n', 'í'))) 2 0.2
# Substitution 0.2
# ('Deletion', ('g', 'a')) 1 0.3333333333333333
# Deletion 0.3333333333333333
# ('Substitution', (('l', 't'), ('l', 'i'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('t', 'y'), ('i', 'd'))) 2 0.2
# Substitution 0.2
# ('Insertion', ('g', 'o')) 7 0.06666666666666667
# Insertion 0.06666666666666667
# ('Substitution', (('g', 'o'), ('g', 'ó'))) 5 0.09090909090909091
# Substitution 0.09090909090909091
# ('Substitution', (('a', 'v'), ('a', 'b'))) 5 0.09090909090909091
# Substitution 0.09090909090909091
# ('Substitution', (('l', 'i'), ('l', 'l'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('c', 'a'), ('c', 'u'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('c', 'e')) 11 0.043478260869565216
# Deletion 0.043478260869565216
# ('Substitution', (('l', 'i'), ('l', 'o'))) 2 0.2
# Substitution 0.2
# ('Deletion', ('n', 'g')) 6 0.07692307692307693
# Deletion 0.07692307692307693
# ('Substitution', (('t', 'i'), ('t', 'e'))) 7 0.06666666666666667
# Substitution 0.06666666666666667
# ('Substitution', (('c', 'e'), ('c', 'é'))) 6 0.07692307692307693
# Substitution 0.07692307692307693
# ('Insertion', ('l', 'u')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Insertion', ('a', 'v')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Insertion', ('v', 'o')) 4 0.1111111111111111
# Insertion 0.1111111111111111
# ('Substitution', (('g', 'a'), ('g', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('t', 'a'), ('t', 'o'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Substitution', (('r', 'u'), ('r', 'o'))) 7 0.06666666666666667
# Substitution 0.06666666666666667
# ('Substitution', (('i', 't'), ('e', 'z'))) 8 0.058823529411764705
# Substitution 0.058823529411764705
# ('Substitution', (('t', 'u'), ('z', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('u', 'd')) 4 0.1111111111111111
# Deletion 0.1111111111111111
# ('Substitution', (('a', 'i'), ('a', 'd'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('p', 'i'), ('p', 'e'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Substitution', (('i', 'o'), ('e', 'ó'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('a', 'o'), ('a', 'ó'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('p', 'e'), ('p', 'i'))) 6 0.07692307692307693
# Substitution 0.07692307692307693
# ('Substitution', (('g', 'e'), ('g', 'a'))) 5 0.09090909090909091
# Substitution 0.09090909090909091
# ('Substitution', (('e', 'c'), ('e', 'q'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('', 'c'), ('', 'q'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('h', 'e'), ('u', 'í'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Substitution', (('e', 'y'), ('e', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('z', 'e'), ('c', 'é'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('e', 'e')) 7 0.06666666666666667
# Deletion 0.06666666666666667
# ('Deletion', ('o', 'i')) 7 0.06666666666666667
# Deletion 0.06666666666666667
# ('Substitution', (('c', 'h'), ('c', 'ó'))) 2 0.2
# Substitution 0.2
# ('Deletion', ('h', 'o')) 5 0.09090909090909091
# Deletion 0.09090909090909091
# ('Substitution', (('c', 'h'), ('c', 'u'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('h', 'o'), ('u', 'e'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('i', 'u')) 1 0.3333333333333333
# Deletion 0.3333333333333333
# ('Substitution', (('c', 'l'), ('c', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('c', 'l'), ('s', 't'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('l', 'e'), ('t', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('e', 't'), ('r', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('i', 'p'), ('i', 'f'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('c', 'i'), ('c', 'í'))) 7 0.06666666666666667
# Substitution 0.06666666666666667
# ('Substitution', (('u', 'm'), ('u', 'n'))) 6 0.07692307692307693
# Substitution 0.07692307692307693
# ('Substitution', (('b', 'e'), ('b', 'i'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Substitution', (('i', 't'), ('i', 'u'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('t', 'y'), ('u', 'd'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('i', 'f')) 2 0.2
# Deletion 0.2
# ('Deletion', ('f', 'i')) 6 0.07692307692307693
# Deletion 0.07692307692307693
# ('Deletion', ('c', 'a')) 1 0.3333333333333333
# Deletion 0.3333333333333333
# ('Substitution', (('f', 'y'), ('f', 'i'))) 17 0.02857142857142857
# Substitution 0.02857142857142857
# ('Substitution', (('l', 'a'), ('l', 'á'))) 9 0.05263157894736842
# Substitution 0.05263157894736842
# ('Substitution', (('e', 'f'), ('a', 'v'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('i', 'c'), ('i', 'g'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('l', 'i'), ('l', 'í'))) 12 0.04
# Substitution 0.04
# ('Substitution', (('l', 'o'), ('l', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('o', 'i'), ('a', 'u'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('h', 'e')) 2 0.2
# Insertion 0.2
# ('Substitution', (('d', 'e'), ('d', 'i'))) 21 0.023255813953488372
# Substitution 0.023255813953488372
# ('Insertion', ('i', 'g')) 3 0.14285714285714285
# Insertion 0.14285714285714285
# ('Substitution', (('c', 'o'), ('c', 'a'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('f', 'f'), ('f', 'é'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('f', 'e')) 2 0.2
# Deletion 0.2
# ('Substitution', (('c', 'o'), ('c', 'u'))) 7 0.06666666666666667
# Substitution 0.06666666666666667
# ('Substitution', (('l', 'a'), ('l', 'o'))) 2 0.2
# Substitution 0.2
# ('Deletion', ('a', 'r')) 3 0.14285714285714285
# Deletion 0.14285714285714285
# ('Deletion', ('e', 'a')) 12 0.04
# Deletion 0.04
# ('Substitution', (('g', 'u'), ('g', 'a'))) 5 0.09090909090909091
# Substitution 0.09090909090909091
# ('Insertion', ('o', 'n')) 9 0.05263157894736842
# Insertion 0.05263157894736842
# ('Substitution', (('g', 'e'), ('g', 'i'))) 8 0.058823529411764705
# Substitution 0.058823529411764705
# ('Substitution', (('a', 'r'), ('a', 'l'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Substitution', (('o', 'l'), ('o', 'r'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('t', 'a'), ('t', 'i'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('o', 'm'), ('o', 'n'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Substitution', (('m', 'm'), ('m', 'i'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('c', 'e'), ('z', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('e', 'm')) 3 0.14285714285714285
# Deletion 0.14285714285714285
# ('Substitution', (('m', 'm'), ('m', 'e'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('t', 't'), ('t', 'i'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('t', 't'), ('t', 'é'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('d', 'i')) 3 0.14285714285714285
# Deletion 0.14285714285714285
# ('Substitution', (('m', 'm'), ('m', 'ú'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('n', 'i'), ('ñ', 'e'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('n', 'y'), ('ñ', 'í'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('i', 's'), ('a', 'c'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('s', 'o'), ('c', 'i'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('p', 'a'), ('p', 'á'))) 6 0.07692307692307693
# Substitution 0.07692307692307693
# ('Substitution', (('e', 'x'), ('e', 'j'))) 8 0.058823529411764705
# Substitution 0.058823529411764705
# ('Insertion', ('j', 'o')) 4 0.1111111111111111
# Insertion 0.1111111111111111
# ('Substitution', (('o', 's'), ('o', 'n'))) 8 0.058823529411764705
# Substitution 0.058823529411764705
# ('Substitution', (('p', 'o'), ('p', 'u'))) 7 0.06666666666666667
# Substitution 0.06666666666666667
# ('Substitution', (('s', 'e'), ('s', 't'))) 5 0.09090909090909091
# Substitution 0.09090909090909091
# ('Substitution', (('e', 'd'), ('t', 'o'))) 5 0.09090909090909091
# Substitution 0.09090909090909091
# ('Deletion', ('e', 'h')) 3 0.14285714285714285
# Deletion 0.14285714285714285
# ('Insertion', ('e', 'b')) 3 0.14285714285714285
# Insertion 0.14285714285714285
# ('Substitution', (('i', 'v'), ('i', 'r'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('h', 'a')) 3 0.14285714285714285
# Insertion 0.14285714285714285
# ('Substitution', (('u', 'd'), ('u', 'i'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Substitution', (('d', 'e'), ('i', 'r'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Deletion', ('c', 'o')) 5 0.09090909090909091
# Deletion 0.09090909090909091
# ('Substitution', (('u', 'i'), ('u', 'c'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('s', 's'), ('s', 'a'))) 7 0.06666666666666667
# Substitution 0.06666666666666667
# ('Substitution', (('i', 'd'), ('i', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('d', 'e'), ('d', 'o'))) 7 0.06666666666666667
# Substitution 0.06666666666666667
# ('Deletion', ('m', 'a')) 1 0.3333333333333333
# Deletion 0.3333333333333333
# ('Deletion', ('a', 'b')) 3 0.14285714285714285
# Deletion 0.14285714285714285
# ('Deletion', ('f', 'o')) 4 0.1111111111111111
# Deletion 0.1111111111111111
# ('Substitution', (('u', 's'), ('u', 'n'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('s', 'e'), ('n', 'd'))) 2 0.2
# Substitution 0.2
# ('Deletion', ('e', 'd')) 4 0.1111111111111111
# Deletion 0.1111111111111111
# ('Substitution', (('s', 'i'), ('s', 'o'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Deletion', ('e', 'c')) 9 0.05263157894736842
# Deletion 0.05263157894736842
# ('Substitution', (('j', 'o'), ('j', 'u'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('e', 'c'), ('e', 'x'))) 5 0.09090909090909091
# Substitution 0.09090909090909091
# ('Substitution', (('u', 'e'), ('u', 'i'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Insertion', ('i', 's')) 2 0.2
# Insertion 0.2
# ('Insertion', ('s', 't')) 3 0.14285714285714285
# Insertion 0.14285714285714285
# ('Substitution', (('e', 'r'), ('i', 's'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('i', 'o'), ('i', 'e'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Substitution', (('o', 'u'), ('e', 'n'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('u', 's'), ('n', 't'))) 2 0.2
# Substitution 0.2
# ('Deletion', ('n', 's')) 1 0.3333333333333333
# Deletion 0.3333333333333333
# ('Substitution', (('n', 'e'), ('n', 'c'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('e', 's'), ('c', 'i'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('s', 's'), ('i', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('e', 'c'), ('a', 'g'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('i', 'm')) 3 0.14285714285714285
# Insertion 0.14285714285714285
# ('Insertion', ('m', 'i')) 10 0.047619047619047616
# Insertion 0.047619047619047616
# ('Substitution', (('s', 'e'), ('s', 'i'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Substitution', (('e', 'q'), ('i', 'g'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Insertion', ('u', 'i')) 2 0.2
# Insertion 0.2
# ('Substitution', (('s', 'o'), ('s', 'u'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Substitution', (('u', 't'), ('u', 'c'))) 14 0.034482758620689655
# Substitution 0.034482758620689655
# ('Substitution', (('u', 'c'), ('u', 'i'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Substitution', (('c', 't'), ('i', 'r'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Deletion', ('p', 't')) 1 0.3333333333333333
# Deletion 0.3333333333333333
# ('Substitution', (('a', 'r'), ('á', 'n'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('r', 'y'), ('n', 'e'))) 2 0.2
# Substitution 0.2
# ('Insertion', ('e', 'o')) 3 0.14285714285714285
# Insertion 0.14285714285714285
# ('Substitution', (('u', 'e'), ('u', 'a'))) 2 0.2
# Substitution 0.2
# ('Insertion', ('r', 'n')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Deletion', ('a', 'c')) 2 0.2
# Deletion 0.2
# ('Substitution', (('c', 't'), ('c', 'i'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('u', 't'), ('u', 'y'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('t', 'o'), ('y', 'e'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('o', 'r'), ('e', 'n'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('x', 'o')) 3 0.14285714285714285
# Insertion 0.14285714285714285
# ('Substitution', (('o', 'p'), ('o', 'b'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Substitution', (('p', 'p'), ('b', 'r'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('p', 'y'), ('p', 'i'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('a', 'z')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Insertion', ('z', 'ó')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Insertion', ('i', 'v')) 3 0.14285714285714285
# Insertion 0.14285714285714285
# ('Substitution', (('p', 's'), ('p', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('t', 'l'), ('t', 'a'))) 5 0.09090909090909091
# Substitution 0.09090909090909091
# ('Substitution', (('l', 'y'), ('a', 'm'))) 5 0.09090909090909091
# Substitution 0.09090909090909091
# ('Substitution', (('e', 'x'), ('e', 'z'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('e', 'l'), ('e', 'j'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('l', 'o'), ('j', 'e'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('n', 't'), ('n', 'd'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Deletion', ('e', 't')) 7 0.06666666666666667
# Deletion 0.06666666666666667
# ('Substitution', (('o', 'u'), ('o', 'r'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('e', 'r'), ('e', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('e', 'o')) 1 0.3333333333333333
# Deletion 0.3333333333333333
# ('Substitution', (('o', 'v'), ('u', 'b'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Substitution', (('v', 'e'), ('b', 'r'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Substitution', (('o', 'w'), ('o', 'b'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('i', 'c'), ('í', 'a'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('n', 'i'), ('n', 'e'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('i', 'u'), ('e', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('r', 'e'), ('r', 'é'))) 5 0.09090909090909091
# Substitution 0.09090909090909091
# ('Insertion', ('o', 's')) 5 0.09090909090909091
# Insertion 0.09090909090909091
# ('Substitution', (('i', 'q'), ('i', 'c'))) 4 0.1111111111111111
# Substitution 0.1111111111111111
# ('Substitution', (('q', 'u'), ('c', 'a'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ('Deletion', ('c', 'r')) 1 0.3333333333333333
# Deletion 0.3333333333333333
# ('Insertion', ('d', 'r')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Substitution', (('r', 'o'), ('r', 'u'))) 3 0.14285714285714285
# Substitution 0.14285714285714285
# ...
# Substitution 0.3333333333333333
# ('Substitution', (('i', 'o'), ('í', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('i', 'p'), ('e', 't'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('p', 'e'), ('t', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('o', 'c')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Substitution', (('t', 'i'), ('m', 'i'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('i', 'z'), ('o', 'c'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('z', 'e'), ('c', 'i'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('c', 't'), ('j', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('t', ''), ('a', 'r'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('h', ''), ('c', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('a', 'l'), ('i', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('e', 'g'), ('é', 'g'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('t', 'e'), ('c', 'i'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('e', 'd'), ('i', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('s', 'a'), ('i', 'e'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('c', 'e'), ('t', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('i', 'r'), ('r', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('e', 'm')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Substitution', (('o', 'n'), ('u', 'e'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('n', 's'), ('e', 's'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('e', ''), ('t', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('o', 'r'), ('a', 'u'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('u', 'r')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Substitution', (('c', 't'), ('n', 'g'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('t', ''), ('g', 'i'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('l', ''), ('r', ''))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('e', 'w'), ('s', 't'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('w', ''), ('t', 'a'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('h', 'y'), ('i', 't'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('y', 't')) 1 0.3333333333333333
# Deletion 0.3333333333333333
# ('Substitution', (('r', 'y'), ('i', 'd'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('i', 'v'), ('í', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('v', 'e'), ('o', ''))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('b', 'e'), ('o', ''))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('o', 'u'), ('e', 'd'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('u', 'n'), ('d', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('r', 'u')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Insertion', ('n', 's')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Substitution', (('b', 'r'), ('d', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('r', 'i'), ('a', 'b'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('i', 'o'), ('b', 'l'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('o', 'u'), ('l', 'e'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('u', 's'), ('e', ''))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('d', ''), ('c', 'h'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('y', ''), ('a', 'c'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('l', 'v')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Substitution', (('v', 'o'), ('b', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('p', 'h'), ('f', 'ó'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('h', 'o'), ('ó', 'n'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('í', 'f')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Insertion', ('f', 'i')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Substitution', (('s', 't'), ('c', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('u', 'p'), ('ú', 'p'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('a', 'l'), ('l', 'l'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('s', 'e'), ('t', 'i'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('e', ''), ('i', 'd'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('n', 'g'), ('a', 'c'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('g', ''), ('c', 'i'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('i', 'ó')) 2 0.2
# Insertion 0.2
# ('Substitution', (('e', 'r'), ('i', 'r'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('e', 'r'), ('i', 'd'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('g', 'n'), ('ñ', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('n', 'a')) 1 0.3333333333333333
# Deletion 0.3333333333333333
# ('Substitution', (('t', 'e'), ('a', ''))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('x', ''), ('s', ''))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('i', 'x'), ('e', 'x'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('a', ''), ('á', ''))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('e', 'r'), ('d', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('t', 'u'), ('d', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('u', 'd'), ('a', 'd'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('í', 'o')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Substitution', (('t', 'h'), ('r', ''))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('u', '')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Substitution', (('a', 'd'), ('á', 'd'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('s', 'p'), ('d', 'e'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('e', 'p')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Substitution', (('z', 'a'), ('c', 'i'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('t', 'i'), ('d', 'í'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('c', 'h'), ('g', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('h', 'i')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Substitution', (('e', 'n'), ('i', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('a', 'n')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Deletion', ('b', 'j')) 1 0.3333333333333333
# Deletion 0.3333333333333333
# ('Deletion', ('b', 'm')) 1 0.3333333333333333
# Deletion 0.3333333333333333
# ('Deletion', ('b', 's')) 1 0.3333333333333333
# Deletion 0.3333333333333333
# ('Deletion', ('b', 't')) 1 0.3333333333333333
# Deletion 0.3333333333333333
# ('Substitution', (('u', 'c'), ('o', 'c'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('f', 'e'), ('r', 'i'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('e', 'r'), ('i', 'm'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('r', 'i'), ('m', 'i'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('s', 'u'), ('a', 'z'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('u', 'g'), ('z', 'ú'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('g', 'a'), ('ú', 'c'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('s', 't'), ('r', 'i'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('u', 'p'), ('o', 'b'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('p', 'e'), ('b', 'e'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('a', 'c'), ('i', 'c'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('i', 's'), ('e', 'n'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('e', 'd'), ('d', 'i'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('u', 'r'), ('o', 'b'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('t', ''), ('h', 'o'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('l', ''), ('s', ''))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('e', 'd'), ('o', 's'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('d', ''), ('s', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('f', ''), ('a', ''))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('t', 'a'), ('e', 's'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('a', 'r'), ('s', 't'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('r', 'r'), ('t', 'r'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('e', 'a'), ('é', ''))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('a', 'p'), ('t', 'e'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('p', 'o'), ('e', 'r'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('o', 't'), ('r', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('e', 'p'), ('é', 'f'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('e', 's'), ('u', 'r'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('s', 's'), ('r', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('n', 'i')) 1 0.3333333333333333
# Deletion 0.3333333333333333
# ('Substitution', (('e', 'p'), ('i', 'b'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('p', 'i'), ('b', 'i'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('t', 'i'), ('c', 'e'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('i', 'a'), ('e', 'r'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('h', 'e'), ('é', 's'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('e', ''), ('s', ''))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('o', 'b'), ('a', 'b'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('o', ''), ('e', ''))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('q', 'u')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Substitution', (('c', 'h'), ('e', ''))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('w', 'e'), ('r', 'r'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('a', 'c'), ('e', 'c'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('a', 'f'), ('á', 'f'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('e', 'r'), ('a', 'n'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('u', 'n')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Insertion', ('a', 't')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Substitution', (('i', 'l'), ('j', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('s', 'o'), ('i', 'c'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('o', 'n'), ('c', 'i'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('i', 'n'), ('o', 'r'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('n', 'g'), ('r', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('g', ''), ('o', 's'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('u', 'l'), ('b', 'l'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('u', 's'), ('r', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('e', ''), ('u', ''))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Deletion', ('o', 'p')) 1 0.3333333333333333
# Deletion 0.3333333333333333
# ('Substitution', (('u', 'm'), ('o', 'm'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('f', ''), ('b', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('o', 'i'), ('e', 's'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('n', 'y'), ('í', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('u', 'l'), ('ú', 'l'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('u', 'n'), ('i', 'n'))) 5 0.09090909090909091
# Substitution 0.09090909090909091
# ('Substitution', (('u', 't'), ('ú', 't'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('u', 'o'), ('í', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('u', 'a'), ('i', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('a', 'b'), ('o', 's'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('b', 'l'), ('s', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('l', 'e'), ('o', ''))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('u', 'e'), ('o', 'r'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('o', 'm'), ('e', 'n'))) 2 0.2
# Substitution 0.2
# ('Substitution', (('m', ''), ('n', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('m', 'o'), ('n', 'o'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('a', 'n'), ('e', ''))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('e', 's'), ('í', 's'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('c', 'e'), ('r', 'r'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('o', 'y'), ('e', 'y'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('e', ''), ('d', ''))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('o', 'r'), ('a', 'n'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('i', 'c'), ('z', ''))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('y', 'b'), ('i', 'b'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('n', 'e'), ('i', 'd'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('e', 's'), ('d', 'a'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('s', 's'), ('a', 'd'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('s', ''), ('d', ''))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('w', 'i'), ('v', 'i'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('e', 'e'), ('u', 'i'))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Substitution', (('e', ''), ('i', ''))) 1 0.3333333333333333
# Substitution 0.3333333333333333
# ('Insertion', ('l', 'ó')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Insertion', ('ó', 'g')) 1 0.3333333333333333
# Insertion 0.3333333333333333
# ('Insertion', ('g', 'i')) 1 0.3333333333333333
# Insertion 0.3333333333333333

# %%
cognates_first.save_weights(BI_INSERTION_0, BI_DELETION_0, BI_SUBSTITUTION_0)
cognates_second.save_weights(BI_INSERTION_1, BI_DELETION_1, BI_SUBSTITUTION_1)

# cognates_first.save_weights(IPA_BI_INSERTION_0, IPA_BI_DELETION_0, IPA_BI_SUBSTITUTION_0)
# cognates_second.save_weights(IPA_BI_INSERTION_1, IPA_BI_DELETION_1, IPA_BI_SUBSTITUTION_1)

# %%
import pickle

to_change = {'ñ': 'n', 'ú': 'u', 'ó': 'o', 'é': 'e', 'á': 'a', 'í': 'i', 'ü': 'u'}

def add_wieghts_ins(weights_file: str, n: int, new_file: str):
    c = 0
    with open(weights_file, 'rb') as f:
        weight_dict = pickle.load(f)
    prev_keys = list(weight_dict.keys())
    for k in prev_keys:
        flag = False
        new_chars = list(k)
#         print(k, weight_dict[k])
        for i in range(n):
            if k[i] and k[i] in 'ñúóéáíü':
                new_chars[i] = to_change[k[i]]
                flag = True
        if flag:
            new_chars = tuple(new_chars)
            if n == 3:
                for tup in [new_chars, k]:
                    if tup not in weight_dict.keys():
                        weight_dict[tup] = 1.0
            if weight_dict[new_chars] != 1.0 and weight_dict[k] != 1.0:
                print('Both appeared!')
                print(new_chars, weight_dict[new_chars])
                print(k, weight_dict[k])
                prev = (1 / (weight_dict[new_chars])) - 1
                curr = (1 / (weight_dict[k])) - 1
                new_wieght = 1 / ((prev + curr) + 1)
                print(new_wieght)
                print()
            elif weight_dict[k] != 1.0:
                print('Spanish appeared!')
                print(new_chars, weight_dict[new_chars])
                print(k, weight_dict[k])
                new_wieght = weight_dict[k]
                print(new_wieght)
                print()
            else:
                new_wieght = weight_dict[new_chars]
            weight_dict[new_chars] = new_wieght
    with open(new_file, 'wb') as f:
        pickle.dump(weight_dict, f)


def add_wieghts_sub(weights_file: str, n: int, new_file: str):
    with open(weights_file, 'rb') as f:
        weight_dict = pickle.load(f)
    prev_keys = list(weight_dict.keys())
    for k in prev_keys:
        flag = False
        new_chars = list(k[1])
        for i in range(n):
            if k[1][i] and k[1][i] in 'ñúóéáíü':
                new_chars[i] = to_change[k[1][i]]
                flag = True
        if flag:
            new_chars = tuple(new_chars)
            if n == 3:
                for tup in [new_chars, k[1]]:
                    if (k[0], tup) not in weight_dict.keys():
                        weight_dict[(k[0], tup)] = 1.0
            if weight_dict[(k[0], new_chars)] != 1.0 and weight_dict[k] != 1.0:
                print('Both appeared!')
                print(new_chars, weight_dict[(k[0], new_chars)])
                print(k, weight_dict[k])
                prev = (1 / (weight_dict[(k[0], new_chars)])) - 1
                curr = (1 / (weight_dict[k])) - 1
                new_wieght = 1 / ((prev + curr) + 1)
                print(new_wieght)
                print()
            elif weight_dict[k] != 1.0:
                print('Spanish appeared!')
                print(new_chars, weight_dict[(k[0], new_chars)])
                print(k, weight_dict[k])
                new_wieght = weight_dict[k]
                print(new_wieght)
                print()
            else:
                new_wieght = weight_dict[(k[0], new_chars)]
            weight_dict[(k[0], new_chars)] = new_wieght
    with open(new_file, 'wb') as f:
        pickle.dump(weight_dict, f)


def check_wieght(weights_file: str, tup: str):
    with open(weights_file, 'rb') as f:
        weight_dict = pickle.load(f)
        if tup in weight_dict.keys():
            print(tup, weight_dict[tup])

# %%
ins = BI_INSERTION_1
new_ins = BI_INSERTION_1 + '_1'
check_wieght(ins, ('d', 'i'))
check_wieght(ins, ('d', 'í'))
add_wieghts_ins(ins, 2, new_ins)
print('After:')
check_wieght(new_ins, ('d', 'i'))

sub = BI_SUBSTITUTION_1
new_sub = BI_SUBSTITUTION_1 + '_1'
check_wieght(sub, (('e', 's'), ('i', 's')))
check_wieght(sub, (('e', 's'), ('í', 's')))
add_wieghts_sub(sub, 2, new_sub)
print('After:')
check_wieght(new_sub, (('e', 's'), ('i', 's')))
# Out:
# ('d', 'i') 0.3333333333333333
# ('d', 'í') 1.0
# ('a', 'ñ') ('a', 'n')
# ('a', 'ú') ('a', 'u')
# ('a', 'ó') ('a', 'o')
# ('a', 'é') ('a', 'e')
# ('a', 'á') ('a', 'a')
# ('a', 'í') ('a', 'i')
# ('a', 'ü') ('a', 'u')
# ('b', 'ñ') ('b', 'n')
# ('b', 'ú') ('b', 'u')
# ('b', 'ó') ('b', 'o')
# ('b', 'é') ('b', 'e')
# ('y', 'é') ('y', 'e')
# ('y', 'á') ('y', 'a')
# ('y', 'í') ('y', 'i')
# ('y', 'ü') ('y', 'u')
# ('z', 'ñ') ('z', 'n')
# ('z', 'ú') ('z', 'u')
# ('z', 'ó') ('z', 'o')
# Spanish appeared!
# ('z', 'o') 1.0
# ('z', 'ó') 0.3333333333333333
# 0.3333333333333333
#
# After:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[98], line 7
#       5 add_wieghts_ins(ins, 2, new_ins)
#       6 print('After:')
# ----> 7 check_wieght(new_ins, ('d', 'i'))
#       9 sub = BI_SUBSTITUTION_1
#      10 new_sub = BI_SUBSTITUTION_1 + '_1'
#
# Cell In[93], line 93, in check_wieght(weights_file, tup)
#      92 def check_wieght(weights_file: str, tup: str):
# ---> 93     with open(weights_file, 'rb') as f:
#      94         weight_dict = pickle.load(f)
#      95         if tup in weight_dict.keys():
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/yuli_zeira/Cognatehood/char_weights/alphabet/new/insertion_1_1'

# %%
import pickle
from numpy import argmin
from sys import argv
from collections import Counter


#  Constants:
N = 3


class TriCognates:

    def __init__(self, cognates_file: str, ipa=False):
        self._is_ipa = ipa
        self._cognates_file = cognates_file
        self._cognates = self.read_cognates()
        self._english_trigrams, self._spanish_trigrams = self.create_trigrams()
        self._insertion, self._deletion, self._substitution = self.create_operations()
        self._operations = list()

    def read_cognates(self) -> list[tuple[str, str]]:
        if not self._is_ipa:
            cognates_list = list()
            with open(self._cognates_file, 'r', encoding='utf-8') as ff:
                for line in ff.readlines():
                    cognate_pair = line.split(',')
                    cognate_pair = (cognate_pair[0].lower(), cognate_pair[1][:-1].lower())
                    cognates_list.append(cognate_pair)
        else:
            with open(self._cognates_file, 'rb') as ff:
                cognates_list = pickle.load(ff)
        return cognates_list

    def make_n_gram(self, word: str, k: int) -> tuple[str]:
        if self._is_ipa:
            tup = [''] + word + ['']
        else:
            tup = [''] + list(word) + ['']
        new_tup = tup[k: k + N]
        return tuple(new_tup)

    def create_trigrams(self) -> tuple[list, list]:
        en_trigrams = list()
        sp_trigrams = list()
        for eng_word, spa_word in self._cognates:
            en_trigrams += [self.make_n_gram(eng_word, i) for i in range(len(eng_word))]
            sp_trigrams += [self.make_n_gram(spa_word, i) for i in range(len(spa_word))]
        return list(set(en_trigrams)), list(set(sp_trigrams))

    def create_operations(self) -> tuple[dict, dict, dict]:
        insertion = dict([(i, 1.0) for i in self._spanish_trigrams])
        deletion = dict([(i, 1.0) for i in self._english_trigrams])
        substitution = dict([((i, j), 1.0) for i in self._english_trigrams for j in self._spanish_trigrams])
        return insertion, deletion, substitution

    def initialize(self, word_1: str, word_2: str) -> tuple[dict, dict]:
        # Set up:
        all_operations, distances = {(-1, -1): []}, {(-1, -1): 0}
        # Initialize the arrays:
        for i in range(len(word_1)):
            distances[(i, -1)] = self._deletion[self.make_n_gram(word_1, i)] + distances[(i - 1, -1)]
            all_operations[(i, -1)] = all_operations[(i - 1, -1)] + [('Deletion', self.make_n_gram(word_1, i))]
        for j in range(len(word_2)):
            distances[(-1, j)] = self._insertion[self.make_n_gram(word_2, j)] + distances[(-1, j - 1)]
            all_operations[(-1, j)] = all_operations[(-1, j - 1)] + [('Insertion', self.make_n_gram(word_2, j))]
        return all_operations, distances

    def edit_distance(self, word_1: str, word_2: str) -> float:
        # Set up:
        if not self._is_ipa:
            word_1, word_2 = word_1.lower(), word_2.lower()
        len_1, len_2 = len(word_1), len(word_2)
        all_operations, distances = self.initialize(word_1, word_2)
        # Fill distances and operations:
        for i in range(len_1):
            for j in range(len_2):
                w1_ngram, w2_ngram = self.make_n_gram(word_1, i), self.make_n_gram(word_2, j)
                if word_1[i] == word_2[j].lower():
                    cost = 0
                    c = []
                else:
                    cost = self._substitution[(w1_ngram, w2_ngram)]
                    c = [('Substitution', (w1_ngram, w2_ngram))]
                curr_operations = [all_operations[(i, j - 1)] + [('Insertion', w2_ngram)],
                                   all_operations[(i - 1, j)] + [('Deletion', w1_ngram)],
                                   all_operations[(i - 1, j - 1)] + c]
                curr_distances = [distances[(i, j - 1)] + self._insertion[w2_ngram],
                                  distances[(i - 1, j)] + self._deletion[w1_ngram],
                                  distances[(i - 1, j - 1)] + cost]
                ind = argmin(curr_distances)
                distances[(i, j)] = curr_distances[ind]
                all_operations[(i, j)] = curr_operations[ind]
        self._operations += all_operations[(len_1 - 1, len_2 - 1)]
        return distances[(len_1 - 1, len_2 - 1)]

    def set_weights(self):
        for pair in self._cognates:
            self.edit_distance(pair[0], pair[1])
        all_ops = Counter(self._operations)
        for op in all_ops.keys():
            print(op, all_ops[op])
            if op[0] == 'Insertion':
                self._insertion[op[1]] = float(1 / (2 * all_ops[op] + 1))
            elif op[0] == 'Deletion':
                self._deletion[op[1]] = float(1 / (2 * all_ops[op] + 1))
            else:
                self._substitution[op[1]] = float(1 / (2 * all_ops[op] + 1))
    
    def save_weights(self, ins: str, de: str, sub: str):
        with open(ins, 'wb') as f:
            pickle.dump(self._insertion, f)
        with open(de, 'wb') as f:
            pickle.dump(self._deletion, f,)
        with open(sub, 'wb') as f:
            pickle.dump(self._substitution, f)

# %%
cognates = TriCognates(COGNATES_LIST, True)

# %%
cognates.set_weights()
# Out:
# ('Substitution', (('', 'æ', 'b'), ('', 'a', 'b'))) 18
# ('Substitution', (('b', 'ə', 'k'), ('b', 'a', 'k'))) 1
# ('Deletion', ('k', 'ə', 's')) 3
# ('Deletion', ('ə', 's', '')) 78
# ('Substitution', (('', 'ə', 'b'), ('', 'a', 'b'))) 21
# ('Substitution', (('b', 'æ', 'n'), ('b', 'a', 'n'))) 7
# ('Substitution', (('d', 'ə', 'n'), ('d', 'o', 'n'))) 3
# ('Insertion', ('n', 'a', '')) 21
# ('Insertion', ('n', 'a', 'd')) 13
# ('Deletion', ('n', 'm', 'ə')) 2
# ('Deletion', ('m', 'ə', 'n')) 9
# ('Deletion', ('ə', 'n', 't')) 14
# ('Deletion', ('n', 't', '')) 18
# ('Substitution', (('b', 'ɹ', 'i'), ('b', 'ɾ', 'e'))) 3
# ('Deletion', ('ɹ', 'i', 'v')) 2
# ('Deletion', ('i', 'v', 'i')) 4
# ('Substitution', (('ɹ', 'ə', 'b'), ('ɾ', 'a', 'b'))) 2
# ('Substitution', (('ɔ', 'ɹ', ''), ('o', 'ɾ', 'a'))) 5
# ('Substitution', (('ɔ', 'ɹ', 'n'), ('o', 'ɾ', 'n'))) 3
# ('Substitution', (('d', 'ʌ', 'l'), ('d', 'u', 'l'))) 2
# ('Substitution', (('', 'ə', 'd'), ('', 'a', 'b'))) 2
# ('Substitution', (('ə', 'd', 'v'), ('a', 'b', 'a'))) 2
# ('Substitution', (('d', 'v', 'æ'), ('b', 'a', 'n'))) 2
# ('Deletion', ('v', 'æ', 'n')) 3
# ('Substitution', (('n', 's', ''), ('n', 'k', ''))) 4
# ('Substitution', (('s', 't', ''), ('s', 'a', 'd'))) 4
# ('Insertion', ('a', 'd', '')) 24
# ('Substitution', (('', 'æ', 'd'), ('', 'b', 'e'))) 1
# ('Substitution', (('æ', 'd', 'v'), ('b', 'e', 'n'))) 1
# ('Deletion', ('d', 'v', 'æ')) 1
# ('Substitution', (('t', 'ɪ', 'd͡ʒ'), ('t', 'a', 'x'))) 1
# ('Substitution', (('ɪ', 'd͡ʒ', ''), ('a', 'x', ''))) 1
# ('Substitution', (('', 'æ', 'd'), ('', 'a', 'b'))) 2
# ('Substitution', (('æ', 'd', 'v'), ('a', 'b', 'e'))) 1
# ('Substitution', (('d', 'v', 'ɛ'), ('b', 'e', 'n'))) 1
# ('Deletion', ('v', 'ɛ', 'n')) 1
# ('Substitution', (('n', 't͡ʃ', 'ɹ̩'), ('n', 't', 'u'))) 3
# ('Substitution', (('t͡ʃ', 'ɹ̩', ''), ('t', 'u', 'ɾ'))) 15
# ('Insertion', ('u', 'ɾ', '')) 16
# ('Substitution', (('d', 'v', 'ɹ̩'), ('d', 'b', 'e'))) 1
# ('Substitution', (('v', 'ɹ̩', 's'), ('b', 'e', 'ɾ'))) 9
# ('Substitution', (('s', 'ɪ', 't'), ('s', 'i', 'd'))) 2
# ('Substitution', (('ɪ', 't', 'i'), ('i', 'd', 'a'))) 17
# ('Deletion', ('', 'æ', 'd')) 1
# ('Deletion', ('æ', 'd', 'v')) 1
# ('Deletion', ('d', 'v', 'a')) 1
# ('Substitution', (('a', 'j', 's'), ('a', 'b', 'i'))) 1
# ('Insertion', ('b', 'i', 's')) 1
# ('Substitution', (('æ', 'd', 'v'), ('a', 'b', 'o'))) 1
# ('Substitution', (('d', 'v', 'ə'), ('b', 'o', 'ɡ'))) 1
# ('Substitution', (('v', 'ə', 'k'), ('o', 'ɡ', 'a'))) 1
# ('Substitution', (('ə', 'k', 'ə'), ('ɡ', 'a', 'd'))) 1
# ('Substitution', (('k', 'ə', 't'), ('a', 'd', ''))) 1
# ('Substitution', (('', 'ɛ', 'ɹ'), ('', 'a', 'e'))) 3
# ('Substitution', (('ɛ', 'ɹ', 'i'), ('a', 'e', 'ɾ'))) 1
# ('Substitution', (('ɹ', 'i', 'ə'), ('e', 'ɾ', 'e'))) 1
# ('Substitution', (('i', 'ə', 'l'), ('ɾ', 'e', ''))) 1
# ('Substitution', (('n', 'ɡ', 'ɑ'), ('n', 'ɡw', 'a'))) 1
# ('Substitution', (('', 'v', 'ə'), ('', 'b', 'a'))) 1
# ('Substitution', (('v', 'ə', 'n'), ('b', 'a', 'i'))) 1
# ('Insertion', ('a', 'i', 'n')) 1
# ('Substitution', (('n', 'ɪ', 'l'), ('n', 'i', 'ʝ'))) 1
# ('Substitution', (('ɪ', 'l', 'ə'), ('i', 'ʝ', ''))) 1
# ('Substitution', (('', 'v', 'ɛ'), ('', 'b', 'a'))) 4
# ('Substitution', (('v', 'ɛ', 'ɹ'), ('b', 'a', 'ɾ'))) 4
# ('Substitution', (('ɛ', 'ɹ', 'i'), ('a', 'ɾ', 'ja'))) 3
# ('Substitution', (('ɹ', 'i', 'e'), ('ɾ', 'ja', 'si'))) 1
# ('Substitution', (('ɹ', 'i', 'd'), ('ɾ', 'ja', 'd'))) 1
# ('Substitution', (('', 'v', 'ɹ̩'), ('', 'b', 'a'))) 1
# ('Deletion', ('v', 'ɹ̩', 'a')) 1
# ('Substitution', (('ɹ', 'i', ''), ('ɾ', 'ja', ''))) 1
# ('Substitution', (('v', 'e', 'j'), ('b', 'a', 's'))) 1
# ('Substitution', (('v', 'æ', 's'), ('b', 'a', 's'))) 1
# ('Substitution', (('', 'v', 'ɛ'), ('', 'b', 'e'))) 12
# ('Substitution', (('v', 'ɛ', 'd͡ʒ'), ('b', 'e', 'xe'))) 3
# ('Substitution', (('ɛ', 'd͡ʒ', 't'), ('e', 'xe', 't'))) 2
# ('Substitution', (('t', 'ə', 'b'), ('t', 'a', ''))) 1
# ('Substitution', (('t', 'ə', 'b'), ('t', 'a', 'l'))) 1
# ('Substitution', (('l', 'z', ''), ('l', 'e', ''))) 1
# ('Substitution', (('ɛ', 'd͡ʒ', 'ə'), ('e', 'xe', 't'))) 1
# ('Substitution', (('', 'v', 'i'), ('', 'b', 'e'))) 2
# ('Substitution', (('v', 'i', 'ə'), ('b', 'e', 'e'))) 1
# ('Substitution', (('i', 'ə', 'm'), ('e', 'e', 'm'))) 1
# ('Substitution', (('v', 'i', 'h'), ('b', 'e', 'ʝ'))) 1
# ('Substitution', (('i', 'h', 'ɪ'), ('e', 'ʝ', 'k'))) 1
# ('Deletion', ('h', 'ɪ', 'k')) 1
# ('Substitution', (('', 'v', 'e'), ('', 'b', 'e'))) 2
# ('Substitution', (('', 'v', 'ə'), ('', 'b', 'e'))) 2
# ('Substitution', (('l', 'ɑ', 's'), ('l', 'o', 'si'))) 1
# ('Substitution', (('d', 'ɹ̩', ''), ('d', 'e', 'd'))) 1
# ('Insertion', ('e', 'd', 'o')) 1
# ('Substitution', (('n', 'd͡ʒ', 'ə'), ('n', 'ɡ', 'a'))) 1
# ('Substitution', (('d͡ʒ', 'ə', 'n'), ('ɡ', 'a', 'n'))) 1
# ('Substitution', (('n', 'ə', 'm'), ('n', 'e', 'n'))) 2
# ('Substitution', (('ə', 'm', ''), ('e', 'n', ''))) 1
# ('Substitution', (('ə', 'm', 'ə'), ('e', 'n', 'o'))) 1
# ('Substitution', (('m', 'ə', 's'), ('n', 'o', 's'))) 1
# ('Substitution', (('', 'v', 'ɹ̩'), ('', 'b', 'e'))) 7
# ('Substitution', (('v', 'ɹ̩', 'b'), ('b', 'e', 'ɾ'))) 2
# ('Substitution', (('b', 'ə', 'l'), ('b', 'a', ''))) 1
# ('Substitution', (('v', 'ɹ̩', 'd'), ('b', 'e', 'ɾ'))) 2
# ('Insertion', ('e', 'ɾ', 'd')) 2
# ('Substitution', (('v', 'ɛ', 'ɹ'), ('b', 'e', 'ɾ'))) 2
# ('Substitution', (('ɛ', 'ɹ', 'ə'), ('e', 'ɾ', 'd'))) 1
# ('Substitution', (('ɹ', 'ə', 't'), ('ɾ', 'd', 'a'))) 1
# ('Substitution', (('v', 'ɹ̩', 'ʒ'), ('b', 'e', 'ɾ'))) 1
# ('Substitution', (('', 'v', 'ɛ'), ('', 'b', 'i'))) 1
# ('Substitution', (('v', 'ɛ', 's'), ('b', 'i', 's'))) 1
# ('Substitution', (('p', 'ɹ̩', 'z'), ('p', 'e', 'ɾ'))) 1
# ('Substitution', (('ɹ̩', 'z', ''), ('e', 'ɾ', ''))) 1
# ('Substitution', (('t', 'ɪ', 'b'), ('t', 'i', 'b'))) 1
# ('Substitution', (('', 'v', 'a'), ('', 'b', 'i'))) 5
# ('Substitution', (('v', 'a', 'j'), ('b', 'i', 'b'))) 2
# ('Substitution', (('b', 'ɹ', 'ə'), ('b', 'ɾ', 'a'))) 1
# ('Substitution', (('v', 'a', 'j'), ('b', 'i', 'si'))) 1
# ('Substitution', (('v', 'a', 'j'), ('b', 'i', 'r'))) 1
# ('Substitution', (('a', 'j', 's'), ('i', 'r', 'e'))) 1
# ('Substitution', (('j', 's', 'ɹ'), ('r', 'e', ''))) 1
# ('Deletion', ('s', 'ɹ', 'o')) 1
# ('Deletion', ('ɹ', 'o', 'j')) 1
# ('Substitution', (('v', 'ə', 's'), ('b', 'e', 'si'))) 1
# ('Substitution', (('ə', 's', 'ɪ'), ('e', 'si', 'n'))) 1
# ('Substitution', (('n', 'ə', 't'), ('n', 'd', 'a'))) 1
# ('Substitution', (('', 'v', 'ɪ'), ('', 'b', 'i'))) 10
# ('Substitution', (('v', 'ɪ', 's'), ('b', 'i', 'si'))) 1
# ('Substitution', (('ɪ', 's', 'ɪ'), ('i', 'si', 's'))) 1
# ('Deletion', ('s', 'ɪ', 's')) 1
# ('Substitution', (('s', 'ɪ', 't'), ('s', 'i', 't'))) 1
# ('Substitution', (('', 'v', 'j'), ('', 'b', 'i'))) 1
# ('Substitution', (('v', 'ɪ', 'd͡ʒ'), ('b', 'i', 'xi'))) 1
# ('Substitution', (('ɪ', 'd͡ʒ', 'ə'), ('i', 'xi', 'l'))) 1
# ('Substitution', (('', 'v', 'a'), ('', 'b', 'jo'))) 4
# ('Substitution', (('v', 'a', 'j'), ('b', 'jo', 'l'))) 4
# ('Substitution', (('l', 'ɪ', 't'), ('l', 'e', 't'))) 1
# ('Substitution', (('', 'v', 'ɹ̩'), ('', 'b', 'i'))) 4
